# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,5,11) #creamos un arreglo con numpy 
y = x**2 #calculamos el cuadrado de ese arreglo

#Graficamos. Por intuición nos retornara la grafica de la función cuadratica x al cuadrado del rango 0 a 5.

plt.plot(x,y)
plt.show()

# %%
#Podemos editar el grafico cambiando el color de la linea o que aparezcan puntos.

fig, ax = plt.subplots(2,2, figsize=(10,10))
ax[0,0].plot(x,y,'r')
ax[0,1].plot(x,y, 'b')
ax[1,0].plot(x,y, 'bo')
ax[1,1].plot(x,y, 'rx')
plt.show()

# %%
#Un poco mas de graficas editadas

fig, (ax1, ax2) = plt.subplots(1,2, figsize = (30,10))
ax1.plot(x,y, 'rs-')
ax2.plot(x,y, 'yD:')

# %% [markdown]
# Y podemos probar con toda la variedad de graficas que tiene el modulo pyplot

# %%
plt.hist(x)
# Out:
# (array([1., 1., 1., 1., 1., 1., 1., 1., 1., 2.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.pie(x)
plt.show()

# %%
plt.scatter(x,y)

# %%
plt.boxplot(x)
plt.show()
